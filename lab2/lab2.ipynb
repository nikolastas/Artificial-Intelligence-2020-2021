# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Νικόλας Τασιόπουλος 03118858
#
# Στοιχεία Μέλους 2: Ναταλία-Μαρία Γρηγοριάδη 03118940

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ### 3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/content/drive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/content/drive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')

import os
# path="D:/Users/Nikos/Projects/AI/lab2/"
path = "~/projects/AI/lab2/" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας

# %%
# %%capture
# #install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# #install pyswip
# !pip3 install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

def clean_map_input(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  text=text.replace(u":",u'' )
  text=text.replace(u"}", u'')
  text=text.replace(u"{", u'')
  text=text.replace(u"[", u'')
  text=text.replace(u"]", u'')
  text=text.replace(u",", u'')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
import pandas as np
import ast
prolog = Prolog()
mydict={}
#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
element=[]
minimu_plot_keywords=999999
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))
  year=getattr(row,'title_year')
  if(year!='UNK'):
    year=str(int(year))
  temp=0
  for genre in getattr(row, 'genres').split("|"):
    temp+=1
    literals.append("genre('"+ movie_title +"','"+ genre +"')")
  minimu_plot_keywords=min(minimu_plot_keywords,temp)
  for plot_keyword in getattr(row, 'plot_keywords').split("|"):
    literals.append("plot_keywords('"+ movie_title +"','"+ clean_text(plot_keyword) +"')")
  
  
  spoken_lang=ast.literal_eval(getattr(row, 'spoken_languages'))
  
  for lang in spoken_lang:
    
    literals.append("spoken_languages('"+ movie_title +"','"+clean_text(lang['iso_639_1'])+"','"+clean_text(lang['name']) +"')")
    # literals.append("iso_to_language_name('"+ clean_text(element['iso_639_1']) +"','"+ clean_text(i['name']) +"')")
  companies = ast.literal_eval(getattr(row, 'production_companies'))
  for company in companies:
    literals.append("production_companies('"+ movie_title +"','"+ clean_text(company['name'])+"','"+str(company['id']) +"')")
    
  
  
  countries=ast.literal_eval((getattr(row, 'production_countries')))
  for country in countries:
    literals.append("production_countries('"+ movie_title +"','"+clean_text(country['iso_3166_1'])+"','"+clean_text(country['name']) +"')")
  
    # literals.append("iso_to_language_name('"+ clean_text(element['iso_639_1']) +"','"+ clean_text(i['name']) +"')")
  #literals.append
  literals.append("homepage('"+movie_title+"','"+clean_text(getattr(row,'homepage'))+"')")
  literals.append("id('"+movie_title+"','"+str(getattr(row,'id'))+"')")
  literals.append("language('"+movie_title+"','"+clean_text(getattr(row,'language'))+"')")
  literals.append("original_title('"+movie_title+"','"+clean_text(getattr(row,'original_title'))+"')")
  literals.append("overview('"+movie_title+"','"+clean_text(getattr(row,'overview'))+"')")
  literals.append("popularity('"+movie_title+"','"+str(getattr(row,'popularity'))+"')")
  literals.append("release_date('"+movie_title+"','"+str(getattr(row,'release_date'))+"')")
  literals.append("gross('"+movie_title+"','"+str(getattr(row,'gross'))+"')")
  literals.append("duration('"+movie_title+"','"+str(getattr(row,'duration'))+"')")
  literals.append("status('"+movie_title+"','"+clean_text(getattr(row,'status'))+"')")
  literals.append("tagline('"+movie_title+"','"+clean_text(getattr(row,'tagline'))+"')")
  literals.append("vote_average('"+movie_title+"','"+str(getattr(row,'vote_average'))+"')")

  
  literals.append("num_voted_users('"+movie_title+"','"+str(getattr(row,'num_voted_users'))+"')")
  literals.append("title_year('"+movie_title+"','"+year+"')")
  literals.append("country('"+movie_title+"','"+clean_text(getattr(row,'country'))+"')")
  literals.append("director_name('"+movie_title+"','"+clean_text(getattr(row,'director_name'))+"')")
  literals.append("actor_1_name('"+movie_title+"','"+clean_text(getattr(row,'actor_1_name'))+"')")
  literals.append("actor_2_name('"+movie_title+"','"+clean_text(getattr(row,'actor_2_name'))+"')")
  literals.append("actor_3_name('"+movie_title+"','"+clean_text(getattr(row,'actor_3_name'))+"')")
  literals.append("actor_name('"+movie_title+"','"+clean_text(getattr(row,'actor_3_name'))+"')")
  literals.append("actor_name('"+movie_title+"','"+clean_text(getattr(row,'actor_2_name'))+"')")
  literals.append("actor_name('"+movie_title+"','"+clean_text(getattr(row,'actor_1_name'))+"')")



  
  
print("minimum plot keywords",minimu_plot_keywords) 
#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
  prolog.assertz(literal)
#   print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
prolog.consult(path + "db.pl")
# Out:
# minimum plot keywords 1

# %%
prolog.consult(path + "db.pl")

# %%
q = prolog.query("sim_studio('Harry Potter and the Chamber of Secrets', Y)")
s = set()
for soln in q:
  m = soln['Y'] 
  if m not in s:
    s.add(soln['Y'])
print(s)
# Out:
# {'The Right Stuff', 'Superman', 'The Art of War', 'The Lost Boys', 'Without Limits', 'Police Academy: Mission to Moscow', 'Slumdog Millionaire', 'Dangerous Liaisons', 'Osmosis Jones', 'Robin Hood: Prince of Thieves', 'Cradle 2 the Grave', 'ATL', 'Catwoman', 'Assassins', 'Batman Forever', 'Kangaroo Jack', 'Charlie and the Chocolate Factory', 'Oceans Eleven', 'The Great Gatsby', 'Private Benjamin', 'Any Given Sunday', 'Superman Returns', 'The Lego Movie', 'Rent', 'The Specialist', 'Batman Begins', 'Rapa Nui', 'The Invasion', 'The Fountain', 'Happy Feet Two', 'The Bridges of Madison County', 'The Good German', 'Night at the Museum', 'Murder by Numbers', 'Pan', 'Ready to Rumble', 'Beautiful Creatures', 'Lucky You', 'RockNRolla', 'See Spot Run', 'Extremely Loud & Incredibly Close', 'Gothika', 'Three Kings', '42', 'August Rush', 'Analyze This', 'The Losers', 'Thir13en Ghosts', 'Sleepers', 'Wild Wild West', 'Outbreak', 'Terminator 3: Rise of the Machines', 'The Color Purple', 'The Bodyguard', 'Must Love Dogs', 'Ri¢hie Ri¢h', 'The Lake House', 'Her', 'Superman II', 'Hot Pursuit', 'American Sniper', 'Lethal Weapon 3', 'White Oleander', 'True Romance', 'A Very Long Engagement', 'Max', 'Eight Legged Freaks', 'North Country', 'Quest for Camelot', 'The Whole Nine Yards', 'Get Smart', 'Red Planet', 'Eyes Wide Shut', 'The Matrix Revolutions', 'Dark Shadows', 'The Outsiders', 'A Time to Kill', 'Exorcist II: The Heretic', 'Nancy Drew', 'A Streetcar Named Desire', 'Ace Ventura: Pet Detective', 'Million Dollar Baby', 'The Shining', 'Beetlejuice', 'The Informant!', 'The Man from U.N.C.L.E.', 'Scooby-Doo 2: Monsters Unleashed', 'Cop Out', 'Sucker Punch', 'The NeverEnding Story', 'The Last Samurai', 'Green Lantern', 'The Hangover Part II', 'Harry Potter and the Half-Blood Prince', 'The Phantom of the Opera', 'Clash of the Titans', 'Mickey Blue Eyes', 'The Departed', 'Training Day', 'Gremlins 2: The New Batch', 'Kiss Kiss Bang Bang', 'Mystic River', 'Sherlock Holmes', 'Percy Jackson & the Olympians: The Lightning Thief', 'Three to Tango', 'Body of Lies', 'The Ant Bully', 'Get Hard', 'This Is Where I Leave You', 'Trouble with the Curve', 'Batman & Robin', 'Practical Magic', 'Chill Factor', 'Winters Tale', 'Batman', 'We Are Marshall', 'Fantastic 4: Rise of the Silver Surfer', 'The Judge', 'Night at the Museum: Battle of the Smithsonian', 'The Town', 'The Pelican Brief', 'Swordfish', 'Firewall', 'The Hangover', 'Inception', 'Jonah Hex', 'Poseidon', 'Batman v Superman: Dawn of Justice', 'Oceans Twelve', 'Woodstock', 'The Perfect Storm', 'Malibus Most Wanted', 'Tin Cup', 'Superman III', '3000 Miles to Graceland', 'Interstellar', 'Flags of Our Fathers', 'Terminator Salvation', 'Space Cowboys', 'Welcome to Collinwood', 'San Andreas', 'Blazing Saddles', 'The Campaign', 'Romeo Must Die', 'Blood Diamond', 'Proof of Life', 'Magic Mike XXL', 'Alexander', 'No Reservations', 'Collateral Damage', '300', 'Barry Lyndon', 'The Dukes of Hazzard', 'Jersey Boys', 'Ninja Assassin', 'Zodiac', 'TMNT', 'Rock Star', 'The Dark Knight', 'Crazy, Stupid, Love.', 'My Fellow Americans', 'Conspiracy Theory', 'Harry Potter and the Prisoner of Azkaban', 'A.I. Artificial Intelligence', 'Battlefield Earth', 'Troy', 'The Time Machine', 'The Island', 'Casablanca', 'One Flew Over the Cuckoos Nest', 'Wyatt Earp', 'Gossip', 'Scooby-Doo', 'Disclosure', 'Christmas with the Kranks', 'Monkeybone', 'I Love You, Beth Cooper', 'The Exorcist', 'Superman IV: The Quest for Peace', 'Cats & Dogs', 'Summer Catch', 'Corpse Bride', 'Lady in the Water', 'Deep Blue Sea', 'JFK', 'Valentine', 'The Lucky One', 'Contagion', 'Once Upon a Time in America', '42nd Street', 'Speed Racer', 'The Hudsucker Proxy', 'Bicentennial Man', 'The Invention of Lying', 'Michael Collins', 'My Dog Skip', 'Watchmen', 'Gangster Squad', 'Coco Before Chanel', 'The Glimmer Man', 'The Negotiator', 'Caddyshack', 'Midnight in the Garden of Good and Evil', 'Krush Groove', 'Sweet November', 'Ghost Ship', 'The Charge of the Light Brigade', ' ...

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
q = prolog.query("find_sim_3('Avatar', Y)")
s = set()
for soln in q:
  m = soln['Y'] 
  if m not in s:
    s.add(soln['Y'])
print(s)
# Out:
# {'The Covenant', 'Cirque du Freak: The Vampires Assistant', 'Mad Max 2: The Road Warrior', 'The Core', 'The Iron Giant', 'The Hobbit: The Battle of the Five Armies', 'Deep Rising', 'Star Trek VI: The Undiscovered Country', 'X-Men', 'Superman', 'Underworld: Evolution', 'Time Bandits', 'Last Action Hero', 'The Incredible Hulk', 'G.I. Joe: Retaliation', 'Lara Croft: Tomb Raider', 'Spider-Man 2', 'A Sound of Thunder', 'Highlander: Endgame', 'The Borrowers', 'Hellboy', 'Jimmy Neutron: Boy Genius', 'Iron Man 3', 'The Inhabited Island', 'How to Train Your Dragon 2', 'RoboCop 3', 'Spawn', 'Green Lantern', 'Thor', 'The Time Machine', 'Titan A.E.', 'Star Trek: First Contact', 'The Lovers', 'The Island', 'Maleficent', 'Jurassic Park III', 'Treasure Planet', 'Beastmaster 2: Through the Portal of Time', 'Congo', 'Escape from L.A.', 'Captain America: Civil War', 'Serenity', 'Transformers: Dark of the Moon', 'The Last Airbender', 'Star Wars', 'The Lost World: Jurassic Park', 'Clash of the Titans', 'The Brothers Grimm', 'Thunderbirds', 'Enders Game', 'Independence Day', 'Journey to the Center of the Earth', 'Street Fighter: The Legend of Chun-Li', 'Aliens vs Predator: Requiem', 'The Last Legion', 'Eragon', 'Ant-Man', 'Star Trek II: The Wrath of Khan', 'Monkeybone', 'Anacondas: The Hunt for the Blood Orchid', 'Dragon Wars: D-War', 'The Matrix Reloaded', 'Star Trek Beyond', 'Transformers', 'Oblivion', 'Superman Returns', 'Thor: The Dark World', 'After Earth', 'Superman IV: The Quest for Peace', 'Priest', 'Megaforce', 'The Amazing Spider-Man', 'Krull', 'Mortal Kombat: Annihilation', 'BloodRayne', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Transformers: Revenge of the Fallen', 'Journey 2: The Mysterious Island', 'The 13th Warrior', 'Star Trek Into Darkness', 'Teenage Mutant Ninja Turtles III', 'Underworld: Rise of the Lycans', 'Paycheck', 'The Black Hole', 'Predators', 'Blade: Trinity', 'Big Trouble in Little China', 'Total Recall', 'The Thief and the Cobbler', 'Men in Black', 'Aliens in the Attic', 'Night at the Museum', 'The Mummy: Tomb of the Dragon Emperor', 'The Host', 'The Saint', 'Daybreakers', 'Six-String Samurai', 'Shin Godzilla', 'Avengers: Age of Ultron', 'Firefox', 'Batman', 'The Empire Strikes Back', 'Armageddon', 'Dungeons & Dragons: Wrath of the Dragon God', 'The Lord of the Rings: The Return of the King', 'Star Wars: Episode II - Attack of the Clones', 'Godzilla 2000', 'Fantastic 4: Rise of the Silver Surfer', 'Mad Max: Fury Road', 'Knowing', 'X-Men: Days of Future Past', 'G-Force', 'The Hunger Games: Catching Fire', 'My Super Ex-Girlfriend', 'Jupiter Ascending', 'Bill & Teds Bogus Journey', 'Star Trek', 'Night at the Museum: Battle of the Smithsonian', 'X-Men: First Class', 'Damnation Alley', 'Iron Man 2', 'Delgo', 'TRON: Legacy', '2012', 'Suicide Squad', 'U.F.O.', 'Reign of Fire', 'The Lord of the Rings: The Fellowship of the Ring', 'Prince of Persia: The Sands of Time', 'The Blood of Heroes', 'Conan the Destroyer', 'Dragonball Evolution', 'In the Name of the King III', 'Star Trek III: The Search for Spock', 'Star Wars: Episode I - The Phantom Menace', 'Jurassic World', 'Battleship', 'Spy Kids 3-D: Game Over', 'Pirates of the Caribbean: On Stranger Tides', 'The Last Witch Hunter', 'Brave', 'The Monkey King 2', 'In the Name of the King: A Dungeon Siege Tale', 'Small Soldiers', 'Dune', 'Star Trek: Generations', 'Timeline', 'The Shadow', 'Star Wars: Clone Wars: Volume 1', 'Star Trek: Nemesis', 'Sky Captain and the World of Tomorrow', 'Resident Evil: Afterlife', 'Warcraft', 'The Mortal Instruments: City of Bones', 'The Hobbit: An Unexpected Journey', 'Logans Run', 'Zathura: A Space Adventure', 'Inception', 'Independence Day: Resurgence', 'Star Trek: Insurrection', 'Star Trek V: The Final Frontier', 'The Amazing Spider-Man 2', 'Batman v Superman: Dawn of Justice', 'Transformers: Age of Extinction', 'Hellboy II: The Golden Army', 'The Hunger Games: Mockingjay - Part 2', 'Return of the Jedi', 'Superman II', 'John Carter ...

# %% [markdown]
# ## Σχολια:
# * Θα προσπαθησουμε να δουμε ποσα αποτελέσματα εχει κάθε query για 5 τυχαιες ταινίες
#
# Παρατηρούμε οτι για τα genres similarity οι περισσότερες ταινίες έχουν το πολύ 2 ίδια genres. Οπότε δεν εχει νοημα για λίγες ταινίες να εξετάσουμε για περισσότερα απο 3 ιδια genres.
# Αποτελέσματα για το παραπάνω και γενικά για αλλα queries βλέπουμε παρακάτω.

# %%
movies= ["'Avatar'", "'Stand by Me'", "'Letters from Iwo Jima'", "'American Pie 2'", "'Kevin Hart: Laugh at My Pain'"]
queries= ["sim_plot_1(", "sim_plot_2(","sim_plot_3(", "sim_plot_4(" , "sim_plot_5(","same_dec(" ]
queries2=["find_sim_5(","find_sim_4(","find_sim_3(", "find_sim_2(", "find_sim_1("]
queries3=["common_director(","sim_studio(", "sim_actor_1(" ]
end_of_query=", Y)"

results={movie:{query:0 for query in queries} for movie in movies}
for movie in movies:
    for query in queries:
        q=prolog.query(query+movie+end_of_query)
        s = set()
        for soln in q:
            m = soln['Y'] 
            if m not in s:
                s.add(soln['Y'])
        results[movie][query]=len(s)
        s=set()
results2={movie:{query:0 for query in queries2} for movie in movies}
for movie in movies:
    for query in queries2:
        q=prolog.query(query+movie+end_of_query)
        s = set()
        for soln in q:
            m = soln['Y'] 
            if m not in s:
                s.add(soln['Y'])
        results2[movie][query]=len(s)
        s=set()
results3={movie:{query:0 for query in queries3} for movie in movies}
for movie in movies:
    for query in queries3:
        q=prolog.query(query+movie+end_of_query)
        s = set()
        for soln in q:
            m = soln['Y'] 
            if m not in s:
                s.add(soln['Y'])
        results3[movie][query]=len(s)
        s=set()

# %%
import matplotlib.pyplot as plt
for movie in movies:
    for query in queries:
        plt.bar(queries, list(results[movie].values()),width=1)
    plt.title(movie)
    plt.show()

# %%
import matplotlib.pyplot as plt
for movie in movies:
    for query in queries2:
        plt.bar(queries2, list(results2[movie].values()),width=1)
    plt.title(movie)
    plt.show()

# %%
import matplotlib.pyplot as plt
for movie in movies:
    for query in queries3:
        plt.bar(queries3, list(results3[movie].values()),width=1)
    plt.title(movie)
    plt.show()

# %%
def prolog_queries(query, ans, s, weighting) :
    myset= set()
    for soln in query:
        m = soln['M'] 
        if m not in myset:
            myset.add(m)
    
    for sol in myset:
        m= sol
        if m not in s:
            s.add(m)
            ans[m]=1
        else:
            tmp = ans[m]
            del ans[m]
            ans[m]=tmp+1*weighting
    query.close()
    return ans
def recommender_1(movie):
    s = set()
    ans={}
    q1 = prolog.query("find_sim_1('" + movie +"',M)")
    ans=prolog_queries(q1, ans, s,5)
    
    q3 = prolog.query("sim_color('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s,2)
    ans=dict(sorted(ans.items(), key=lambda x: x[1], reverse=True))
    
    return ans
def recommender_2(movie):
    s = set()
    ans={}
    q1 = prolog.query("find_sim_2('" + movie +"',M)")
    ans=prolog_queries(q1, ans, s, 5)
    q3 = prolog.query("sim_color('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 1)
    q3 = prolog.query("sim_plot_1('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 3)
    q3 = prolog.query("same_dec('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 1)
    
    # q4 = prolog.query("sim_actor_1('" + movie +"',M)")
    # ans=prolog_queries(q4, ans, s, 1.5)
    ans=dict(sorted(ans.items(), key=lambda x: x[1], reverse=True))
    
    return ans
def recommender_3(movie):
    s= set()
    ans = {}
    q1 = prolog.query("find_sim_2('" + movie +"',M)")
    ans=prolog_queries(q1, ans, s,3)
    q2 = prolog.query("sim_plot_2('" + movie +"',M)")
    ans=prolog_queries(q2, ans, s,3)
    q3 = prolog.query("sim_color('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 0.5)
    q4 = prolog.query("sim_actor_1('" + movie +"',M)")
    ans=prolog_queries(q4, ans, s, 1)
    q5 = prolog.query("sim_studio('" + movie +"',M)")
    ans=prolog_queries(q5, ans, s, 2)
    q6 = prolog.query("common_director('" + movie +"',M)")
    ans=prolog_queries(q6, ans, s, 0.5)
    ans=dict(sorted(ans.items(), key=lambda x: x[1], reverse=True))
    

    return ans
def recommender_4(movie):
    s= set()
    ans = {}
    q1 = prolog.query("find_sim_2('" + movie +"',M)")
    ans=prolog_queries(q1, ans, s, 1)
    q1 = prolog.query("find_sim_3('" + movie +"',M)")
    ans=prolog_queries(q1, ans, s, 2)
    q2 = prolog.query("sim_plot_2('" + movie +"',M)")
    ans=prolog_queries(q2, ans, s, 2)
    q3 = prolog.query("sim_color('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 0.5)
    q4 = prolog.query("sim_actor_1('" + movie +"',M)")
    ans=prolog_queries(q4, ans, s, 1.5)
    q5 = prolog.query("sim_studio('" + movie +"',M)")
    ans=prolog_queries(q5, ans, s,1)
    q6 = prolog.query("common_director('" + movie +"',M)")
    ans=prolog_queries(q6, ans, s, 1)
    q3 = prolog.query("same_dec('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 0.5)
    ans=dict(sorted(ans.items(), key=lambda x: x[1], reverse=True))
    
    return ans
def recommender_5(movie):
    
    s= set()
    ans = {}
    
    q1 = prolog.query("find_sim_3('" + movie +"',M)")
    ans=prolog_queries(q1, ans, s,3)
    q2 = prolog.query("sim_plot_3('" + movie +"',M)")
    ans=prolog_queries(q2, ans, s,3)
    q3 = prolog.query("sim_color('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 0.5)
    q4 = prolog.query("sim_actor_1('" + movie +"',M)")
    ans=prolog_queries(q4, ans, s, 1)
    q5 = prolog.query("sim_studio('" + movie +"',M)")
    ans=prolog_queries(q5, ans, s, 1)
    q6 = prolog.query("sim_actors_2('" + movie +"',M)")
    ans=prolog_queries(q6, ans, s, 0.5)
    q7 = prolog.query("common_director('" + movie +"',M)")
    ans=prolog_queries(q7, ans, s, 0.5)
    q3 = prolog.query("same_dec('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 0.5)
    q3 = prolog.query("sim_spoken_lang('" + movie +"',M)")
    ans=prolog_queries(q3, ans, s, 1)

    ans=dict(sorted(ans.items(), key=lambda x: x[1], reverse=True))
    return ans

# %%
list(recommender_1('Avatar'))[:5]
# Out:
# ['Multiplicity',
#  'Transcendence',
#  'Royal Kill',
#  'The Core',
#  'Underworld: Evolution']

# %%
list(recommender_2('Avatar'))[:5]
# Out:
# ['Journey to the Center of the Earth',
#  'Zathura: A Space Adventure',
#  'Red Planet',
#  'The Matrix Revolutions',
#  'Men in Black II']

# %%
list(recommender_3('Avatar'))[:5]
# Out:
# ['Alien', 'Aliens', 'Alien³', 'Titan A.E.', 'Independence Day']

# %%
list(recommender_4('Avatar'))[:5]
# Out:
# ['Star Trek Into Darkness',
#  'Titan A.E.',
#  'Planet of the Apes',
#  'Independence Day',
#  'Predators']

# %%
list(recommender_5('Avatar'))[:5]
# Out:
# ['Star Trek Into Darkness',
#  'Predators',
#  'The Fifth Element',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'John Carter']

# %% [markdown]
# Αρχικά παρατηρούμε ότι οι recommender_4 & 5 , έχουν κοινά στοιχεία.
#
# Περιμέναμε να γίνει αυτό , καθώς παρουσιάζουν κοινά στοιχεία με μεγαλο βαθμό ομοιότητας, πχ find_sim_3 -> genres, sim_plot_3-> plot keywords.
#
# Τέλος πρέπει να πούμε ότι για το μέρος 3 βάζουμε σε σχόλια το sort για λιγότερη χρονική πολυπλοκότητα.

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(1)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, recomender, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1

    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')
        

        similar_movies = recomender(movie)

        for movie, similarity in similar_movies.items():
            # print(movie, similarity)
            if movie not in movie_score:
                movie_score[movie] = rating_weights[int(rating)] * similarity
            else:
                movie_score[movie] += rating_weights[int(rating)] * similarity
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score, minimum_score=0):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > minimum_score)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, recommender_1, 10)
    real, pred = predict_example(test_ratings, movie_score, 0)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5635660804008603
# recall: 0.7138888888888889
# f1: 0.5492502051948291

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, recommender_1, 30)
    real, pred = predict_example(test_ratings, movie_score, 0)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5107022876339785
# recall: 0.9944444444444445
# f1: 0.6747921676399862

# %% [markdown]
# Παρατηρούμε οτι για τον recommender_1 το συστημα προτασης ταινιών ειναι αρκετά καλό για 10 ταινίες, ωστόσω οχι τοσο καλό για περισσότερες πχ 30.

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, recommender_2, 10)
    real, pred = predict_example(test_ratings, movie_score, 1)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5058190309727687
# recall: 0.8972222222222221
# f1: 0.6409450565020799

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, recommender_2, 30)
    real, pred = predict_example(test_ratings, movie_score, 1)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")

# %% [markdown]
# Στον προηγούμενο recommnder ειχαμε πολυ υψηλά βάρη στο similarity μεταξύ ταινιών λογω του μικρού πλήθους χαρακτηριστικών.
#
# Εδώ , στον recommender_2 μπορούμε να κόψουμε ουσιαστικά αρκετά απο αυτά, με similarity <= 1 .

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, recommender_3, 30)
    real, pred = predict_example(test_ratings, movie_score, 2)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5117797876842455
# recall: 0.9972222222222221
# f1: 0.6763992082278578

# %% [markdown]
# Παρόμοια βλέπουμε οτι για περισσότερες ταινίες θέλουμε μεγαλύτερο recommender

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, recommender_4, 10)
    real, pred = predict_example(test_ratings, movie_score, 0)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5147118281199202
# recall: 0.9847222222222222
# f1: 0.6758797467975238

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, recommender_5, 5)
    real, pred = predict_example(test_ratings, movie_score, 0)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# /home/nikos/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.45930273036656005
# recall: 0.8819444444444444
# f1: 0.6035978273554675

# %% [markdown]
# Βλεπουμε οτι για 5 τυχαιες ταινίες έχουμε πολύ καλό αποτέλεσμα.
